# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read a comma-separated values (csv) file into DataFrame.
#
# The data folder contains a file named "newark_tree_data.csv". Read this file into a dataframe.
#
#
# resources:
# * [Pandas read csv docs](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html#pandas.read_csv)

# %%
df = pd.read_csv("newark_tree_data.csv")

# %%
# Create DataFrame here.
df
# Out:
#           ID                 ON  \
# 0       11.0          Elan Park
# 1       12.0          Elan Park
# 2       13.0          Elan Park
# 3       14.0          Elan Park
# 4       15.0          Elan Park
# ...      ...                ...
# 4188  4189.0      New London Rd
# 4189  4190.0      New London Rd
# 4190  4191.0      New London Rd
# 4191  4192.0  Old Paper Mill Rd
# 4192  4193.0  Old Paper Mill Rd
#
#                                                    AREA  ADDRESS  \
# 0                                             Elan Park        2
# 1                                             Elan Park        2
# 2                                             Elan Park        2
# 3                                             Elan Park        2
# 4                                             Elan Park        2
# ...                                                 ...      ...
# 4188  New London Road on EAST side North of Clevelan...      124
# 4189  New London Road on EAST side North of Clevelan...      126
# 4190  New London Road on EAST side North of Clevelan...      126
# 4191                           Old Paper Mill Road Park        0
# 4192                           Old Paper Mill Road Park        0
#
#                  STREET  SITE   SIDE  ASSIGNED                COMMON  \
# 0           Blue Hen Rg  11.0  Front     False   arborvitae, eastern
# 1           Blue Hen Rg  12.0  Front     False   arborvitae, eastern
# 2           Blue Hen Rg  13.0  Front     False   pine, eastern white
# 3           Blue Hen Rg  14.0  Front     False  whitecedar, Atlantic
# 4           Blue Hen Rg  15.0  Front     False  whitecedar, Atlantic
# ...                 ...   ...    ...       ...                   ...
# 4188      New London Rd   1.0  Front     False   Japanese pagodatree
# 4189      New London Rd   1.0  Front     False         oak, sawtooth
# 4190      New London Rd   2.0  Front     False   Japanese pagodatree
# 4191  Old Paper Mill Rd   1.0  Front     False    sycamore, American
# 4192  Old Paper Mill Rd   2.0  Front     False            ash, white
#
#                     BOTANICAL  ... IMPROPMULC  IMPROPPRUN NUTRIENTD   PEST  \
# 0          Thuja occidentalis  ...      False       False     False  False
# 1          Thuja occidentalis  ...      False       False     False  False
# 2               Pinus strobus  ...      False       False     False  False
# 3      Chamaecyparis thyoides  ...      False       False     False  False
# 4      Chamaecyparis thyoides  ...      False       False     False  False
# ...                       ...  ...        ...         ...       ...    ...
# 4188  Styphnolobium japonicum  ...      False       False     False  False
# 4189       Quercus acutissima  ...      False       False     False  False
# 4190  Styphnolobium japonicum  ...      False       False     False  False
# 4191    Platanus occidentalis  ...      False       False     False  False
# 4192       Fraxinus americana  ...      False       False     False  False
#
#      GIRDLING STRESS OHUTILITY  TOP_HEIGHT CROWN_M CROWN_DIE
# 0       False  False        No          40    0-5%      0-5%
# 1       False  False        No          41    0-5%      0-5%
# 2        True  False        No          54    0-5%     6-10%
# 3        True  False        No          57  11-15%    26-30%
# 4        True  False        No          55  11-15%    21-25%
# ...       ...    ...       ...         ...     ...       ...
# 4188    False  False        No          50  16-20%     6-10%
# 4189    False  False        No          55  11-15%     6-10%
# 4190    False  False        No          45  16-20%    11-15%
# 4191    False  False        No          80  21-25%     6-10%
# 4192    False   True        No          70  21-25%    11-15%
#
# [4193 rows x 54 columns]

# %%
# Display the first few rows of the DataFrame here.
df.head(10)
# Out:
#      ID         ON       AREA  ADDRESS       STREET  SITE   SIDE  ASSIGNED  \
# 0  11.0  Elan Park  Elan Park        2  Blue Hen Rg  11.0  Front     False
# 1  12.0  Elan Park  Elan Park        2  Blue Hen Rg  12.0  Front     False
# 2  13.0  Elan Park  Elan Park        2  Blue Hen Rg  13.0  Front     False
# 3  14.0  Elan Park  Elan Park        2  Blue Hen Rg  14.0  Front     False
# 4  15.0  Elan Park  Elan Park        2  Blue Hen Rg  15.0  Front     False
# 5  16.0  Elan Park  Elan Park        2  Blue Hen Rg  16.0  Front     False
# 6  17.0  Elan Park  Elan Park        2  Blue Hen Rg  17.0  Front     False
# 7  18.0  Elan Park  Elan Park        2  Blue Hen Rg  18.0  Front     False
# 8  19.0  Elan Park  Elan Park        2  Blue Hen Rg  19.0  Front     False
# 9  20.0  Elan Park  Elan Park        2  Blue Hen Rg  20.0  Front     False
#
#                  COMMON               BOTANICAL  ... IMPROPMULC  IMPROPPRUN  \
# 0   arborvitae, eastern      Thuja occidentalis  ...      False       False
# 1   arborvitae, eastern      Thuja occidentalis  ...      False       False
# 2   pine, eastern white           Pinus strobus  ...      False       False
# 3  whitecedar, Atlantic  Chamaecyparis thyoides  ...      False       False
# 4  whitecedar, Atlantic  Chamaecyparis thyoides  ...      False       False
# 5   pine, eastern white           Pinus strobus  ...      False       False
# 6  whitecedar, Atlantic  Chamaecyparis thyoides  ...      False       False
# 7   pine, eastern white           Pinus strobus  ...      False       False
# 8   arborvitae, eastern      Thuja occidentalis  ...      False       False
# 9   arborvitae, eastern      Thuja occidentalis  ...      False       False
#
#   NUTRIENTD   PEST GIRDLING STRESS OHUTILITY  TOP_HEIGHT CROWN_M CROWN_DIE
# 0     False  False    False  False        No          40    0-5%      0-5%
# 1     False  False    False  False        No          41    0-5%      0-5%
# 2     False  False     True  False        No          54    0-5%     6-10%
# 3     False  False     True  False        No          57  11-15%    26-30%
# 4     False  False     True  False        No          55  11-15%    21-25%
# 5     False  False     True  False        No          55   6-10%    16-20%
# 6     False  False     True  False        No          55  21-25%    31-35%
# 7     False  False     True  False        No          55  11-15%    11-15%
# 8     False  False    False  False        No          56  11-15%    16-20%
# 9     False  False     True  False        No          55   6-10%    11-15%
#
# [10 rows x 54 columns]

# %%
# How many columns does the DataFrame contain?
df.count(axis='columns')
# Out:
# 0       50
# 1       50
# 2       50
# 3       50
# 4       51
#         ..
# 4188    50
# 4189    50
# 4190    50
# 4191    50
# 4192    50
# Length: 4193, dtype: int64

# %%
# What attributes (columns) does this DataFrame contain?
df.columns
# Out:
# Index(['ID', 'ON', 'AREA', 'ADDRESS', 'STREET', 'SITE', 'SIDE', 'ASSIGNED',
#        'COMMON', 'BOTANICAL', 'CULTIVAR', 'DBH', 'REMOVAL', 'STEMS', 'COND',
#        'MAINTPRIM', 'OBSERVE', 'INSPECT', 'LOCATION', 'NOTES', 'DATE', 'TIME',
#        'STAFF', 'XCOORD', 'YCOORD', 'FAILURE', 'LIKELIHOOD', 'TARGET',
#        'CONSEQ', 'RISK', 'UNIQUEID', 'EDITTIME', 'SPREAD', 'HEIGHT',
#        'CLEARANCE', 'DECAYCL', 'DECAYT', 'DECAYRF', 'DAMC', 'DAMT', 'DAMRF',
#        'CAVITYCL', 'CAVITYT', 'CAVITYRF', 'IMPROPMULC', 'IMPROPPRUN',
#        'NUTRIENTD', 'PEST', 'GIRDLING', 'STRESS', 'OHUTILITY', 'TOP_HEIGHT',
#        'CROWN_M', 'CROWN_DIE'],
#       dtype='object')

# %% [markdown]
# Upon reviewing the columns of the DataFrame, we see that there is already a column named ID that is well suited for an index column.
#
# For the purposes of this lab, we are only going to need a few of the available attributes. The attributes we wish to keep are listed below:
# * ID
# * UNIQUEID
# * COMMON
# * BOTANICAL
# * COND
# * RISK
# * HEIGHT
#
# Let's provide the index_col and the usecols args when we invoke the read_csv method.

# %%
# Create the new DataFrame here.
df1 = df[['ID','UNIQUEID','COMMON','BOTANICAL','COND','RISK','HEIGHT']]
df1.set_index('ID', inplace=True)
df1
# Out:
#                  UNIQUEID                COMMON                BOTANICAL  \
# ID
# 11.0    LM 20150929141218   arborvitae, eastern       Thuja occidentalis
# 12.0    LM 20150929141418   arborvitae, eastern       Thuja occidentalis
# 13.0    LM 20150929141844   pine, eastern white            Pinus strobus
# 14.0    LM 20150929142424  whitecedar, Atlantic   Chamaecyparis thyoides
# 15.0    LM 20150929143018  whitecedar, Atlantic   Chamaecyparis thyoides
# ...                   ...                   ...                      ...
# 4189.0  SR 20151104153437   Japanese pagodatree  Styphnolobium japonicum
# 4190.0  SR 20151104153555         oak, sawtooth       Quercus acutissima
# 4191.0  SR 20151104153647   Japanese pagodatree  Styphnolobium japonicum
# 4192.0  SR 20151104160909    sycamore, American    Platanus occidentalis
# 4193.0  SR 20151104161140            ash, white       Fraxinus americana
#
#              COND RISK  HEIGHT
# ID
# 11.0         Good  Low      40
# 12.0    Very Good  Low      40
# 13.0         Good  Low      54
# 14.0         Fair  Low      56
# 15.0         Fair  Low      55
# ...           ...  ...     ...
# 4189.0       Good  Low      50
# 4190.0       Good  Low      55
# 4191.0       Fair  Low      45
# 4192.0       Good  Low      80
# 4193.0       Fair  Low      70
#
# [4193 rows x 6 columns]

# %%
# Display the first few rows of the new DataFrame here.
df1.head(10)
# Out:
#                UNIQUEID                COMMON               BOTANICAL  \
# ID
# 11.0  LM 20150929141218   arborvitae, eastern      Thuja occidentalis
# 12.0  LM 20150929141418   arborvitae, eastern      Thuja occidentalis
# 13.0  LM 20150929141844   pine, eastern white           Pinus strobus
# 14.0  LM 20150929142424  whitecedar, Atlantic  Chamaecyparis thyoides
# 15.0  LM 20150929143018  whitecedar, Atlantic  Chamaecyparis thyoides
# 16.0  LM 20150929143352   pine, eastern white           Pinus strobus
# 17.0  LM 20150929143905  whitecedar, Atlantic  Chamaecyparis thyoides
# 18.0  LM 20150929144155   pine, eastern white           Pinus strobus
# 19.0  LM 20150929144438   arborvitae, eastern      Thuja occidentalis
# 20.0  LM 20150929144602   arborvitae, eastern      Thuja occidentalis
#
#            COND RISK  HEIGHT
# ID
# 11.0       Good  Low      40
# 12.0  Very Good  Low      40
# 13.0       Good  Low      54
# 14.0       Fair  Low      56
# 15.0       Fair  Low      55
# 16.0       Fair  Low      55
# 17.0       Fair  Low      55
# 18.0       Fair  Low      55
# 19.0       Fair  Low      55
# 20.0       Fair  Low      55

# %% [markdown]
# The data narritive specifies that 4,193 sites were inventoried. Use the DataFrame shape attribute to verify the number of rows.

# %%
# How many rows does your DataFrame contain.
df1.count(axis = 'rows')
# Out:
# UNIQUEID     4193
# COMMON       4193
# BOTANICAL    4193
# COND         4087
# RISK         4087
# HEIGHT       4193
# dtype: int64

# %% [markdown]
# Let's look at the distribution of data for the HEIGHT attribute.

# %%
# What is the min height?
df1['HEIGHT'].min()
# Out:
# 0

# %%
# What is the max height?
df1['HEIGHT'].max()
# Out:
# 140

# %%
# How do we acquire count, mean, standard deviation, and distribution information from the DataFrame 
# by invoking a single method?
df1.describe()
# Out:
#             HEIGHT
# count  4193.000000
# mean     55.311472
# std      36.293489
# min       0.000000
# 25%      23.000000
# 50%      50.000000
# 75%      86.000000
# max     140.000000

# %% [markdown]
# # Plot a histogram using the HEIGHT attribute.
#
# resources:
# * [Magic commands](https://ipython.readthedocs.io/en/stable/interactive/magics.html)
# * [Pandas Series Hist](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.hist.html#pandas.Series.plot.hist)

# %%
# Apply magic command to display matplotlib images inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# %matplotlib inline

# %%
x = np.arange(0,4*np.pi,0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
# Create a histogram using the HEIGHT attribute here
x = df1['HEIGHT']
plt.hist(x, bins = 50)
plt.show()

# %% [markdown]
# The data narrative specifies the following:
# "A total of 4,193 sites were inventoried, including 4,087 trees, 100 stumps, and 6 vacant planting sites"
#
# Earlier, we were able to validate the total number of entries in the DataFrame. Let's now dig in a bit deeper and validate the stumps and vacant planting sites.

# %%
# How many entries are stumps
df_stump = df1.loc[df1['COMMON'] == 'stump']
df_stump
# Out:
#                  UNIQUEID COMMON BOTANICAL COND RISK  HEIGHT
# ID
# 119.0   LM 20151001093501  stump     stump  NaN  NaN       0
# 120.0   LM 20151001093612  stump     stump  NaN  NaN       0
# 269.0   LM 20151005101319  stump     stump  NaN  NaN       0
# 270.0   LM 20151005101403  stump     stump  NaN  NaN       0
# 271.0   LM 20151005101436  stump     stump  NaN  NaN       0
# ...                   ...    ...       ...  ...  ...     ...
# 4095.0  SR 20151103154447  stump     stump  NaN  NaN       0
# 4149.0  SR 20151104115722  stump     stump  NaN  NaN       0
# 4167.0  SR 20151104142636  stump     stump  NaN  NaN       0
# 4168.0  SR 20151104142704  stump     stump  NaN  NaN       0
# 4175.0  SR 20151104151721  stump     stump  NaN  NaN       0
#
# [100 rows x 6 columns]

# %%
# How many entries are vacant sites
df_vac = df1.loc[df1['COMMON'] == '']
df_vac
# Out:
# Empty DataFrame
# Columns: [UNIQUEID, COMMON, BOTANICAL, COND, RISK, HEIGHT]
# Index: []

# %%
# Do these number add up?

# %% [markdown]
# # Plot a bar graph using the COND attribute.
#
# resources:
# * [Pandas Series Bar](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.bar.html#pandas.Series.plot.bar)

# %%
# How can we determine all of the possible values describing the condition of a tree and their associated counts?
df2 = df1['COND'].value_counts()
df2
# Out:
# Fair         1598
# Good         1168
# Poor          402
# Very Good     381
# Dead          218
# Excellent     163
# Very Poor      83
# Critical       74
# Name: COND, dtype: int64

# %%
# Were these already in the order you would want them to be in order for a graph to make sense? 
# If not, reorder  the Series.
df2_sort = df2.sort_values(ascending=True, axis=0)
df2_sort
# Out:
# Critical       74
# Very Poor      83
# Excellent     163
# Dead          218
# Very Good     381
# Poor          402
# Good         1168
# Fair         1598
# Name: COND, dtype: int64

# %%
# Plot the Series here
df2_sort.plot.bar(title='Condition of a tree')

plt.show()

# %%
# How many entries have missing values for the COND attribute? Why are these values missing?
print(df1['COND'].isnull)
# Out:
# <bound method Series.isnull of ID
# 11.0           Good
# 12.0      Very Good
# 13.0           Good
# 14.0           Fair
# 15.0           Fair
#             ...
# 4189.0         Good
# 4190.0         Good
# 4191.0         Fair
# 4192.0         Good
# 4193.0         Fair
# Name: COND, Length: 4193, dtype: object>

# %% [markdown]
# # Plot a pie chart using the RISK attribute.

# %% [markdown]
# resources:
# * [Pandas Series Pie](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.pie.html#pandas.Series.plot.pie)
# * [matplotlib pie chart docs](https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie)

# %%
# How can we determine all of the possible values describing the RISK associated with each tree
# along with the corresponding row counts?
df_risk = df[['UNIQUEID','RISK','CONSEQ']]
df_risk
# Out:
#                UNIQUEID RISK       CONSEQ
# 0     LM 20150929141218  Low        Minor
# 1     LM 20150929141418  Low  Significant
# 2     LM 20150929141844  Low  Significant
# 3     LM 20150929142424  Low   Negligible
# 4     LM 20150929143018  Low  Significant
# ...                 ...  ...          ...
# 4188  SR 20151104153437  Low        Minor
# 4189  SR 20151104153555  Low        Minor
# 4190  SR 20151104153647  Low        Minor
# 4191  SR 20151104160909  Low        Minor
# 4192  SR 20151104161140  Low        Minor
#
# [4193 rows x 3 columns]

# %%
# Create an array containing the colors green, yellow, and orange
# When we create our pie chart, the colors should be associated with the attributes according to the specifications below:
# Green -> Low
# Yellow -> Moderate
# Orange -> High
colors = ['GREEN','YELLOW','ORANGE']
Data = {'RISK':}
df = DataFrame(Data,columns=['RISK'],index = ['LOW','MODERATE','HIGH'])

print (df)
# Out:
#   File "<ipython-input-232-cf57f0e885b9>", line 7
#     Data = {'RISK':}
#                    ^
# SyntaxError: invalid syntax

# %%
# Plot the pie chart here

# %%
# How many entries have missing values for the RISK attribute? Why are these values missing?

# %% [markdown]
# # Indexing

# %%
# Display row by position 1

# %%
# Display row by label 1
